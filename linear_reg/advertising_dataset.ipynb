# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
dataset_advt = pd.read_csv("/home/negi/negi/Machine_Learn/Simple_Linear_regression/Advertising.csv")
print(dataset_advt)
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# 19           20  147.3   23.9       19.1   14.6
# 20           21  218.4   27.7       53.4   18.0
# 21           22  237.4    5.1       23.5   12.5
# 22           23   13.2   15.9       49.6    5.6
# 23           24  228.3   16.9       26.2   15.5
# 24           25   62.3   12.6       18.3    9.7
# 25           26  262.9    3.5       19.5   12.0
# 26           27  142.9   29.3       12.6   15.0
# 27           28  240.1   16.7       22.9   15.9
# 28           29  248.8   27.1       22.9   18.9
# 29           30   70.6   16.0       40.8   10.5
# ..          ...    ...    ...        ...    ...
# 170         171   50.0   11.6       18.4    8.4
# 171         172  164.5   20.9       47.4   14.5
# 172         173   19.6   20.1       17.0    7.6
# 173         174  168.4    7.1       12.8   11.7
# 174         175  222.4    3.4       13.1   11.5
# 175         176  276.9   48.9       41.8   27.0
# 176         177  248.4   30.2       20.3   20.2
# 177         178  170.2    7.8       35.2   11.7
# 178         179  276.7    2.3       23.7   11.8
# 179         180  165.6   10.0       17.6   12.6
# 180         181  156.6    2.6        8.3   10.5
# 181         182  218.5    5.4       27.4   12.2
# 182         183   56.2    5.7       29.7    8.7
# 183         184  287.6   43.0       71.8   26.2
# 184         185  253.8   21.3       30.0   17.6
# 185         186  205.0   45.1       19.6   22.6
# 186         187  139.5    2.1       26.6   10.3
# 187         188  191.1   28.7       18.2   17.3
# 188         189  286.0   13.9        3.7   15.9
# 189         190   18.7   12.1       23.4    6.7
# 190         191   39.5   41.1        5.8   10.8
# 191         192   75.5   10.8        6.0    9.9
# 192         193   17.2    4.1       31.6    5.9
# 193         194  166.8   42.0        3.6   19.6
# 194         195  149.7   35.6        6.0   17.3
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
X = dataset_advt[["TV", "radio", "newspaper", "sales"]]
print(X)
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# 5      8.7   48.9       75.0    7.2
# 6     57.5   32.8       23.5   11.8
# 7    120.2   19.6       11.6   13.2
# 8      8.6    2.1        1.0    4.8
# 9    199.8    2.6       21.2   10.6
# 10    66.1    5.8       24.2    8.6
# 11   214.7   24.0        4.0   17.4
# 12    23.8   35.1       65.9    9.2
# 13    97.5    7.6        7.2    9.7
# 14   204.1   32.9       46.0   19.0
# 15   195.4   47.7       52.9   22.4
# 16    67.8   36.6      114.0   12.5
# 17   281.4   39.6       55.8   24.4
# 18    69.2   20.5       18.3   11.3
# 19   147.3   23.9       19.1   14.6
# 20   218.4   27.7       53.4   18.0
# 21   237.4    5.1       23.5   12.5
# 22    13.2   15.9       49.6    5.6
# 23   228.3   16.9       26.2   15.5
# 24    62.3   12.6       18.3    9.7
# 25   262.9    3.5       19.5   12.0
# 26   142.9   29.3       12.6   15.0
# 27   240.1   16.7       22.9   15.9
# 28   248.8   27.1       22.9   18.9
# 29    70.6   16.0       40.8   10.5
# ..     ...    ...        ...    ...
# 170   50.0   11.6       18.4    8.4
# 171  164.5   20.9       47.4   14.5
# 172   19.6   20.1       17.0    7.6
# 173  168.4    7.1       12.8   11.7
# 174  222.4    3.4       13.1   11.5
# 175  276.9   48.9       41.8   27.0
# 176  248.4   30.2       20.3   20.2
# 177  170.2    7.8       35.2   11.7
# 178  276.7    2.3       23.7   11.8
# 179  165.6   10.0       17.6   12.6
# 180  156.6    2.6        8.3   10.5
# 181  218.5    5.4       27.4   12.2
# 182   56.2    5.7       29.7    8.7
# 183  287.6   43.0       71.8   26.2
# 184  253.8   21.3       30.0   17.6
# 185  205.0   45.1       19.6   22.6
# 186  139.5    2.1       26.6   10.3
# 187  191.1   28.7       18.2   17.3
# 188  286.0   13.9        3.7   15.9
# 189   18.7   12.1       23.4    6.7
# 190   39.5   41.1        5.8   10.8
# 191   75.5   10.8        6.0    9.9
# 192   17.2    4.1       31.6    5.9
# 193  166.8   42.0        3.6   19.6
# 194  149.7   35.6        6.0   17.3
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
q = X.describe()
print(q)
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
x = X.head()
print(x)
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
y = dataset_advt.sales
print(y)
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
# 5       7.2
# 6      11.8
# 7      13.2
# 8       4.8
# 9      10.6
# 10      8.6
# 11     17.4
# 12      9.2
# 13      9.7
# 14     19.0
# 15     22.4
# 16     12.5
# 17     24.4
# 18     11.3
# 19     14.6
# 20     18.0
# 21     12.5
# 22      5.6
# 23     15.5
# 24      9.7
# 25     12.0
# 26     15.0
# 27     15.9
# 28     18.9
# 29     10.5
#        ...
# 170     8.4
# 171    14.5
# 172     7.6
# 173    11.7
# 174    11.5
# 175    27.0
# 176    20.2
# 177    11.7
# 178    11.8
# 179    12.6
# 180    10.5
# 181    12.2
# 182     8.7
# 183    26.2
# 184    17.6
# 185    22.6
# 186    10.3
# 187    17.3
# 188    15.9
# 189     6.7
# 190    10.8
# 191     9.9
# 192     5.9
# 193    19.6
# 194    17.3
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
sns.jointplot(x='sales',y='TV',data=dataset_advt,kind='scatter')
# Out:
# /home/negi/negi/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(dataset_advt['newspaper'])

# %%
sns.jointplot(x='sales',y='TV',data=dataset_advt,kind='hex')

# %%
sns.jointplot(x='sales',y='TV',data=dataset_advt,kind='reg')

# %%
sns.pairplot(dataset_advt,palette='coolwarm')

# %%
sns.rugplot(dataset_advt['sales'])

# %%
sns.lmplot(x='sales',y='TV',size=2,aspect=4,data=dataset_advt)
# Out:
# /home/negi/negi/lib/python3.5/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset_advt[["TV", "radio", "newspaper"]],dataset_advt.sales,test_size=0.3,random_state = 42 )
print("X_train value:" , X_train)
print("X_test value :",X_test)
print("y_train value :",y_train)
print("y_test value :",y_test)

print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# X_train value:         TV  radio  newspaper
# 169  284.3   10.6        6.4
# 97   184.9   21.0       22.0
# 31   112.9   17.4       38.6
# 12    23.8   35.1       65.9
# 35   290.7    4.1        8.5
# 119   19.4   16.0       22.3
# 42   293.6   27.7        1.8
# 189   18.7   12.1       23.4
# 90   134.3    4.9        9.3
# 136   25.6   39.0        9.3
# 51   100.4    9.6        3.6
# 127   80.2    0.0        9.2
# 162  188.4   18.1       25.6
# 41   177.0   33.4       38.7
# 118  125.7   36.9       79.2
# 113  209.6   20.6       10.7
# 26   142.9   29.3       12.6
# 139  184.9   43.9        1.7
# 100  222.4    4.3       49.8
# 111  241.7   38.0       23.2
# 2     17.2   45.9       69.3
# 77   120.5   28.5       14.2
# 46    89.7    9.9       35.7
# 187  191.1   28.7       18.2
# 191   75.5   10.8        6.0
# 85   193.2   18.4       65.7
# 161   85.7   35.8       49.3
# 36   266.9   43.8        5.0
# 190   39.5   41.1        5.8
# 61   261.3   42.7       54.7
# ..     ...    ...        ...
# 48   227.2   15.8       49.9
# 88    88.3   25.5       73.4
# 21   237.4    5.1       23.5
# 57   136.2   19.2       16.6
# 160  172.5   18.1       30.7
# 192   17.2    4.1       31.6
# 129   59.6   12.0       43.1
# 37    74.7   49.4       45.7
# 157  149.8    1.3       24.3
# 193  166.8   42.0        3.6
# 1     44.5   39.3       45.1
# 52   216.4   41.7       39.6
# 149   44.7   25.8       20.6
# 130    0.7   39.6        8.7
# 151  121.0    8.4       48.7
# 103  187.9   17.2       17.9
# 99   135.2   41.7       45.9
# 116  139.2   14.3       25.6
# 87   110.7   40.6       63.2
# 74   213.4   24.6       13.1
# 121   18.8   21.7       50.4
# 199  232.1    8.6        8.7
# 20   218.4   27.7       53.4
# 188  286.0   13.9        3.7
# 71   109.8   14.3       31.7
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [140 rows x 3 columns]
# X_test value :         TV  radio  newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# 18    69.2   20.5       18.3
# 55   198.9   49.4       60.0
# 75    16.9   43.7       89.4
# 150  280.7   13.9       37.0
# 104  238.2   34.3        5.3
# 135   48.3   47.0        8.5
# 137  273.7   28.9       59.7
# 164  117.2   14.7        5.4
# 76    27.5    1.6       20.7
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# 195   38.2    3.7       13.8
# 29    70.6   16.0       40.8
# 19   147.3   23.9       19.1
# 143  104.6    5.7       34.4
# 86    76.3   27.5       16.0
# 114   78.2   46.8       34.5
# 173  168.4    7.1       12.8
# 5      8.7   48.9       75.0
# 126    7.8   38.9       50.6
# 117   76.4    0.8       14.8
# 73   129.4    5.7       31.3
# 140   73.4   17.0       12.9
# 98   289.7   42.3       51.2
# 172   19.6   20.1       17.0
# 96   197.6    3.5        5.9
# y_train value : 169    15.0
# 97     15.5
# 31     11.9
# 12      9.2
# 35     12.8
# 119     6.6
# 42     20.7
# 189     6.7
# 90     11.2
# 136     9.5
# 51     10.7
# 127     8.8
# 162    14.9
# 41     17.1
# 118    15.9
# 113    15.9
# 26     15.0
# 139    20.7
# 100    11.7
# 111    21.8
# 2       9.3
# 77     14.2
# 46     10.6
# 187    17.3
# 191     9.9
# 85     15.2
# 161    13.3
# 36     25.4
# 190    10.8
# 61     24.2
#        ...
# 48     14.8
# 88     12.9
# 21     12.5
# 57     13.2
# 160    14.4
# 192     5.9
# 129     9.7
# 37     14.7
# 157    10.1
# 193    19.6
# 1      10.4
# 52     22.6
# 149    10.1
# 130     1.6
# 151    11.6
# 103    14.7
# 99     17.2
# 116    12.2
# 87     16.0
# 74     17.0
# 121     7.0
# 199    13.4
# 20     18.0
# 188    15.9
# 71     12.4
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: sales, Length: 140, dtype: float64
# y_test value : 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# 79     11.0
# 197    12.8
# 38     10.1
# 24      9.7
# 122    11.6
# 195     7.6
# 29     10.5
# 19     14.6
# 143    10.4
# 86     12.0
# 114    14.6
# 173    11.7
# 5       7.2
# 126     6.6
# 117     9.4
# 73     11.0
# 140    10.9
# 98     25.4
# 172     7.6
# 96     11.7
# Name: sales, dtype: float64
# 140
# 60
# 140
# 60

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
regressor.intercept_
print("intercept Value : ", regressor.intercept_)

regressor.coef_
print(regressor.coef_ )
# Out:
# intercept Value :  2.7089490925159048
# [0.04405928 0.1992875  0.00688245]

# %%
y_pred = regressor.predict( X_test )
print("y_predction value : ",y_pred)
# Out:
# y_predction value :  [16.5653963  21.18822792 21.55107058 10.88923816 22.20231988 13.35556872
#  21.19692502  7.35028523 13.27547079 15.12449511  9.01443026  6.52542825
#  14.30205991  8.97026042  9.45679576 12.00454351  8.91549403 16.15619251
#  10.29582883 18.72473553 19.76821818 13.77469028 12.49638908 21.53501762
#   7.60860741  5.6119801  20.91759483 11.80627665  9.08076637  8.51412012
#  12.17604891  9.9691939  21.73008956 12.77770578 18.1011362  20.07590796
#  14.26202556 20.93826535 10.83938827  4.38190607  9.51332406 12.40486324
#  10.17045434  8.09081363 13.16388427  5.2243552   9.28893833 14.09330719
#   8.69024497 11.66119763 15.71848432 11.63156862 13.35360735 11.1531472
#   6.33636845  9.76157954  9.4195714  24.25516546  7.69519137 12.15317572]

# %%
test_pred_df = pd.DataFrame({ 'actual': y_test, 'predicted ': np.round(y_pred, 2), 'residuals': y_test - y_pred })
print(test_pred_df)

###################
from sklearn import metrics
rmse = np.sqrt( metrics.mean_squared_error(y_test,y_pred))
round( rmse, 2 )

print("root mean square value : ",round(rmse,2))
## calculating R-squared  it's means that if the value is closer to 100 % then our model is good

metrics.r2_score( y_test, y_pred )
print("R- squared value ",metrics.r2_score( y_test, y_pred ))
# Out:
#      actual  predicted   residuals
# 95     16.9       16.57   0.334604
# 15     22.4       21.19   1.211772
# 30     21.4       21.55  -0.151071
# 158     7.3       10.89  -3.589238
# 128    24.7       22.20   2.497680
# 115    12.6       13.36  -0.755569
# 69     22.3       21.20   1.103075
# 170     8.4        7.35   1.049715
# 174    11.5       13.28  -1.775471
# 45     14.9       15.12  -0.224495
# 66      9.5        9.01   0.485570
# 182     8.7        6.53   2.174572
# 165    11.9       14.30  -2.402060
# 78      5.3        8.97  -3.670260
# 186    10.3        9.46   0.843204
# 177    11.7       12.00  -0.304544
# 56      5.5        8.92  -3.415494
# 152    16.6       16.16   0.443807
# 82     11.3       10.30   1.004171
# 68     18.9       18.72   0.175264
# 124    19.7       19.77  -0.068218
# 16     12.5       13.77  -1.274690
# 148    10.9       12.50  -1.596389
# 93     22.2       21.54   0.664982
# 65      9.3        7.61   1.691393
# 60      8.1        5.61   2.488020
# 84     21.7       20.92   0.782405
# 67     13.4       11.81   1.593723
# 125    10.6        9.08   1.519234
# 132     5.7        8.51  -2.814120
# 9      10.6       12.18  -1.576049
# 18     11.3        9.97   1.330806
# 55     23.7       21.73   1.969910
# 75      8.7       12.78  -4.077706
# 150    16.1       18.10  -2.001136
# 104    20.7       20.08   0.624092
# 135    11.6       14.26  -2.662026
# 137    20.8       20.94  -0.138265
# 164    11.9       10.84   1.060612
# 76      6.9        4.38   2.518094
# 79     11.0        9.51   1.486676
# 197    12.8       12.40   0.395137
# 38     10.1       10.17  -0.070454
# 24      9.7        8.09   1.609186
# 122    11.6       13.16  -1.563884
# 195     7.6        5.22   2.375645
# 29     10.5        9.29   1.211062
# 19     14.6       14.09   0.506693
# 143    10.4        8.69   1.709755
# 86     12.0       11.66   0.338802
# 114    14.6       15.72  -1.118484
# 173    11.7       11.63   0.068431
# 5       7.2       13.35  -6.153607
# 126     6.6       11.15  -4.553147
# 117     9.4        6.34   3.063632
# 73     11.0        9.76   1.238420
# 140    10.9        9.42   1.480429
# 98     25.4       24.26   1.144835
# 172     7.6        7.70  -0.095191
# 96     11.7       12.15  -0.453176
# root mean square value :  1.95
# R- squared value  0.8609466508230368

# %%
residuals = (y_test-y_pred)
print("residuals value: ",residuals)
# Out:
# residuals value:  95     0.334604
# 15     1.211772
# 30    -0.151071
# 158   -3.589238
# 128    2.497680
# 115   -0.755569
# 69     1.103075
# 170    1.049715
# 174   -1.775471
# 45    -0.224495
# 66     0.485570
# 182    2.174572
# 165   -2.402060
# 78    -3.670260
# 186    0.843204
# 177   -0.304544
# 56    -3.415494
# 152    0.443807
# 82     1.004171
# 68     0.175264
# 124   -0.068218
# 16    -1.274690
# 148   -1.596389
# 93     0.664982
# 65     1.691393
# 60     2.488020
# 84     0.782405
# 67     1.593723
# 125    1.519234
# 132   -2.814120
# 9     -1.576049
# 18     1.330806
# 55     1.969910
# 75    -4.077706
# 150   -2.001136
# 104    0.624092
# 135   -2.662026
# 137   -0.138265
# 164    1.060612
# 76     2.518094
# 79     1.486676
# 197    0.395137
# 38    -0.070454
# 24     1.609186
# 122   -1.563884
# 195    2.375645
# 29     1.211062
# 19     0.506693
# 143    1.709755
# 86     0.338802
# 114   -1.118484
# 173    0.068431
# 5     -6.153607
# 126   -4.553147
# 117    3.063632
# 73     1.238420
# 140    1.480429
# 98     1.144835
# 172   -0.095191
# 96    -0.453176
# Name: sales, dtype: float64

# %%
sns.distplot(residuals)
# Out:
# /home/negi/negi/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
